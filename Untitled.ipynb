# %%
import pandas as pd
import numpy as np
df = pd.read_excel(r'D:\\WORK\\Pattern project\\EXTENDED_1.xlsx')
df.head()
# Out:
#             Timestamp  Score         ID  Gender   Height  Weight  CGPA  \
# 0  3/23/2019 19:10:21  0 / 2  151341004     NaN      5.7     NaN   NaN
# 1  3/24/2019 14:29:31  0 / 1  151341021    Male     5'3"    61.0  3.48
# 2  3/24/2019 14:33:11  0 / 1  151341012    Male      5.8    78.0  2.90
# 3  3/24/2019 14:34:00  0 / 1  151341008  Female      5.3    48.0  3.33
# 4  3/24/2019 14:33:55  0 / 1  151341011    Male  161.544    59.0  3.72
#
#   Daily spent time in social media (hour)     Hometown  \
# 0                                     NaN          NaN
# 1                     2019-05-02 00:00:00   Lakshmipur
# 2                            Below 1 hour   Munshiganj
# 3                     2019-05-02 00:00:00     Bagerhat
# 4                     2019-05-02 00:00:00  kishoregonj
#
#   How many days in a week you feel more energetic  \
# 0                                             NaN
# 1                                               4
# ...

# %%
for index, row in df.iterrows():
    print(index, row['ID'])
# Out:
# 0 151341004
# 1 151341021
# 2 151341012
# 3 151341008
# 4 151341011
# 5 151341029
# 6 151341005
# 7 151341006
# 8 151341023
# 9 151341009
# 10 151341014
# 11 151341026
# 12 151341004
# 13 151341019
# 14 151341013
# 15 151341022
# 16 151341027
# 17 151341015
# 18 151341037
# 19 151341038
# 20 151341035
# 21 141440899
# 22 141440945
# 23 151341028
# 24 151340998
# 25 151340979
# 26 151341000
# 27 151340977
# 28 151340983
# 29 151340981
# 30 151340988
# 31 151340994
# 32 151340985
# 33 151340996
# 34 151340976
# 35 151340986
# 36 151340980
# 37 151341001
# 38 151340990
# 39 151340995
# 40 151340984
# 41 151340991
# 42 151340982
# 43 151340992
# 44 151340905
# 45 151340898
# 46 151340919
# 47 151340897
# 48 151340907
# 49 151340917
# 50 151340906
# 51 151340900
# 52 151340903
# 53 151340909
# 54 151340918
# 55 151340902
# 56 151340913
# 57 151340920
# 58 151340894
# 59 151340914
# 60 151340912
# 61 151340901
# 62 151340910
# 63 151340916
# 64 151340911
# 65 151340904
# 66 151340925
# ...

# %%
df[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\WORK\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-78a33f69c558> in <module>
# ----> 1 df[1]
#
# ...

# %%
df.iloc[0,2]
# Out:
# 151341004

# %%
df.iloc[0,2] = 007
# Out:
#   File "<ipython-input-9-ef1dbe573ebe>", line 1
#     df.iloc[0,2] = 007
#                      ^
# SyntaxError: invalid token

# %%
df.at[0,2] = 1234

# %%
df.iloc[0,2]
# Out:
# 151341004

# %%
import pandas as pd
import numpy as np
df = pd.read_excel(r'D:\\WORK\\Pattern project\\EXTENDED_1.xlsx')
df2 = pd.read_excel(r'D:\\WORK\\Pattern project\\DATASET_1.xlsx')
i=0
j=0
for index, row in df.iterrows():
    for index2, row2 in df2.iterrows():
        if df.at[index, 'ID'] == df2.at[index2, 'ID']:
            print('match found!')
            df.set_value(index, 'Place Name', df2.at[index2, 'Place Name'])
            df.set_value(index, 'Latitude', df2.at[index2, 'Latitude'])
            df.set_value(index, 'Longitude', df2.at[index2, 'Longitude'])
            df.set_value(index, 'Place Name2', df2.at[index2, 'Place Name2'])
            df.set_value(index, 'Latitude2', df2.at[index2, 'Latitude2'])
            df.set_value(index, 'Longitude2', df2.at[index2, 'Longitude2'])
            df.set_value(index, 'Food you like most', df2.at[index2, 'Food you like most'])
            df.set_value(index, 'Leisure time activity', df2.at[index2, 'Leisure time activity'])
            df.set_value(index, 'Future plan', df2.at[index2, 'Future plan'])
            df.set_value(index, 'Typically your days are started at:', df2.at[index2, 'Typically your days are started at:'])
            break;
# Out:
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# ...

# %%
df2 = pd.read_excel(r'D:\\WORK\\Pattern project\\DATASET_2.xlsx')
for index, row in df.iterrows():
    for index2, row2 in df2.iterrows():
        if df.at[index, 'ID'] == df2.at[index2, 'ID']:
            print('match found!')
            df.set_value(index, 'Place Name', df2.at[index2, 'Place Name'])
            df.set_value(index, 'Latitude', df2.at[index2, 'Latitude'])
            df.set_value(index, 'Longitude', df2.at[index2, 'Longitude'])
            df.set_value(index, 'Place Name2', df2.at[index2, 'Place Name2'])
            df.set_value(index, 'Latitude2', df2.at[index2, 'Latitude2'])
            df.set_value(index, 'Longitude2', df2.at[index2, 'Longitude2'])
            df.set_value(index, 'Food you like most', df2.at[index2, 'Food you like most'])
            df.set_value(index, 'Leisure time activity', df2.at[index2, 'Leisure time activity'])
            df.set_value(index, 'Future plan', df2.at[index2, 'Future plan'])
            df.set_value(index, 'Typically your days are started at:', df2.at[index2, 'Typically your days are started at:'])
            break;
# Out:
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# ...

# %%
df2 = pd.read_excel(r'D:\\WORK\\Pattern project\\DATASET_4.xlsx')
for index, row in df.iterrows():
    for index2, row2 in df2.iterrows():
        if df.at[index, 'ID'] == df2.at[index2, 'ID']:
            print('match found!')
            df.set_value(index, 'Place Name', df2.at[index2, 'Place Name'])
            df.set_value(index, 'Latitude', df2.at[index2, 'Latitude'])
            df.set_value(index, 'Longitude', df2.at[index2, 'Longitude'])
            df.set_value(index, 'Place Name2', df2.at[index2, 'Place Name2'])
            df.set_value(index, 'Latitude2', df2.at[index2, 'Latitude2'])
            df.set_value(index, 'Longitude2', df2.at[index2, 'Longitude2'])
            df.set_value(index, 'Food you like most', df2.at[index2, 'Food you like most'])
            df.set_value(index, 'Leisure time activity', df2.at[index2, 'Leisure time activity'])
            df.set_value(index, 'Future plan', df2.at[index2, 'Future plan'])
            df.set_value(index, 'Typically your days are started at:', df2.at[index2, 'Typically your days are started at:'])
            break;
# Out:
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# ...

# %%
df2 = pd.read_excel(r'D:\\WORK\\Pattern project\\DATASET_5.xlsx')
for index, row in df.iterrows():
    for index2, row2 in df2.iterrows():
        if df.at[index, 'ID'] == df2.at[index2, 'ID']:
            print('match found!')
            df.set_value(index, 'Place Name', df2.at[index2, 'Place Name'])
            df.set_value(index, 'Latitude', df2.at[index2, 'Latitude'])
            df.set_value(index, 'Longitude', df2.at[index2, 'Longitude'])
            df.set_value(index, 'Place Name2', df2.at[index2, 'Place Name2'])
            df.set_value(index, 'Latitude2', df2.at[index2, 'Latitude2'])
            df.set_value(index, 'Longitude2', df2.at[index2, 'Longitude2'])
            df.set_value(index, 'Food you like most', df2.at[index2, 'Food you like most'])
            df.set_value(index, 'Leisure time activity', df2.at[index2, 'Leisure time activity'])
            df.set_value(index, 'Future plan', df2.at[index2, 'Future plan'])
            df.set_value(index, 'Typically your days are started at:', df2.at[index2, 'Typically your days are started at:'])
            break;
# Out:
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# ...

# %%
df2 = pd.read_excel(r'D:\\WORK\\Pattern project\\DATASET_6.xlsx')
for index, row in df.iterrows():
    for index2, row2 in df2.iterrows():
        if df.at[index, 'ID'] == df2.at[index2, 'ID']:
            print('match found!')
            df.set_value(index, 'Place Name', df2.at[index2, 'Place Name'])
            df.set_value(index, 'Latitude', df2.at[index2, 'Latitude'])
            df.set_value(index, 'Longitude', df2.at[index2, 'Longitude'])
            df.set_value(index, 'Place Name2', df2.at[index2, 'Place Name2'])
            df.set_value(index, 'Latitude2', df2.at[index2, 'Latitude2'])
            df.set_value(index, 'Longitude2', df2.at[index2, 'Longitude2'])
            df.set_value(index, 'Food you like most', df2.at[index2, 'Food you like most'])
            df.set_value(index, 'Leisure time activity', df2.at[index2, 'Leisure time activity'])
            df.set_value(index, 'Future plan', df2.at[index2, 'Future plan'])
            df.set_value(index, 'Typically your days are started at:', df2.at[index2, 'Typically your days are started at:'])
            break;
# Out:
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# match found!
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   import sys
# D:\WORK\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# ...

# %%
for index, row in df.iterrows():
    print(index, row['Place Name'])
# Out:
# 0 Mirpur
# 1 Modhubag
# 2 Niketan Bazar
# 3 modhubag
# 4 Mohakhali DOHS
# 5 Dhanmondi
# 6 Rajarbag
# 7 Mirpur
# 8 Mirpur
# 9 Mohanogor
# 10 Gopibag
# 11 Rampura
# 12 Shantinagar
# 13 Siddeswari
# 14 Narinda
# 15 Mugdapara
# 16 Shahidbag
# 17 Tejgaon
# 18 Rampura
# 19 Aftabnagar
# 20 Goran
# 21 Tejgaon
# 22 Mohammadpur
# 23 Rampura
# 24 Mirpur
# 25 Rampura
# 26 Maniknagar
# 27 India
# 28 Uttara
# 29 Khilgaon
# 30 Tejgaon
# 31 Siddheshwari
# 32 Maniknagar
# 33 Maniknagar
# 34 Mirpur-12
# 35 Mirpur
# 36 Motijheel
# 37 Hazaribagh
# 38 Tejgaon
# 39 Rampura
# 40 Rampura
# 41 Gulshan 1
# 42 Mirpur-1
# 43 Malibagh
# 44 Niketon
# 45 Shantinagar
# 46 Mohakhali
# 47 Kathalbagan
# 48 Panthapath
# 49 Mirpur-10
# 50 Dhaka Cantonment
# 51 Goran
# 52 Banasree
# 53 Niketon
# 54 Shaymoli
# 55 Bangshal
# 56 Dania
# 57 Jurain
# 58 Lalbag
# 59 Rampura
# 60 Rampura
# 61 Dania
# 62 Mohammadpur
# 63 Jigatola
# 64 Shamoli
# 65 Green Corner
# 66 Shahjahanpur
# 67 Khilgaon
# 68 Banani
# 69 Uttara
# ...

# %%
df.to_csv(r'D:\\WORK\\Pattern project\\All_Data.csv')

# %%
df.to_excel(r'D:\\WORK\\Pattern project\\All_Data.xlsx')
