# %%
import pandas as pd
import numpy as np
df = pd.read_csv('All_Data.csv')
df.head()
# Out:
#    Unnamed: 0           Timestamp  Score         ID  Gender        Height  \
# 0           0   3/29/2019 0:23:23  0 / 1  121440946    Male  5 ft 10 inch
# 1           1   3/29/2019 3:00:10  0 / 1  131440910  Female          5'3"
# 2           2  3/28/2019 23:40:52  0 / 1  131440969    Male           5.4
# 3           3  3/28/2019 23:17:47  0 / 1  141340900    Male         5'8''
# 4           4  3/24/2019 15:31:24  0 / 1  141440899  Female         156cm
#
#    Weight  CGPA Daily spent time in social media (hour)    Hometown  \
# 0      90  2.34                            Below 1 hour     Comilla
# 1      42  2.50                     2019-05-02 00:00:00       Bogra
# 2      60  2.80                     2019-05-02 00:00:00  Narsinghdi
# 3      70  2.47                            Above 5 hour    Rajshahi
# 4      76  3.62                     2019-05-02 00:00:00  Chittagong
#
#                   ...                      Place Name   Latitude  Longitude  \
# ...

# %%
import nltk
nltk.edit_distance("Yes", "Yes i will")
# Out:
# 7

# %%
for c in df.columns:
    print(c)
# Out:
# Unnamed: 0
# Timestamp
# Score
# ID
# Gender
# Height
# Weight
# CGPA
# Daily spent time in social media (hour)
# Hometown
# How many days in a week you feel more energetic
# Favorite transport mode
# Favorite food names
# Expected food price of that favorite food
# Month cost for that particular food
# What do you like home delivery or eat in the restaurant
# University travel cost monthly
# Hobby
# Travel package you prefer
# Sickness-frequency in a month
# Favorite food in summer/winter/rainy season
# Food flavor
# Hangout location(Spend most of the time)
# Typically you go out with
# Travel budget
# favourite restaurant
# Unnamed: 25
# Restaurant location
# Live with family(y/n)
# Are you happy with current situation?
# Number of programming hours spent per day
# Sleep duration
# Do you start your day by planning(y/n)
# Do you have online shopping experience (y/n)
# Do you use products for grooming(y/n)
# Favourite food in rainy season
# Prefers(food_quality/environment)
# ...

# %%
table = pd.pivot_table(df, values='ID', index=['Future plan','Would you still pursue your goal if the motive behind it is fulfilled in another way?'], aggfunc='count')
table
# Out:
#                                                                                       ID
# Future plan                       Would you still pursue your goal if the motive ...
# Aerospace Engineer                Yes                                                  1
# Afflulent                         Yes                                                  1
# Ai Architecture                   yes                                                  1
# Any job                           yes                                                  1
# BCS                               No                                                   1
#                                   No.                                                  1
#                                   Yes                                                  2
#                                   may be                                               1
#                                   yes                                                  1
# ...
