# %%
import pandas as pd
import numpy as np
df = pd.read_csv('All_Data.csv')
table = pd.pivot_table(df, values='Gender', index=['Do you think it is a good idea to go to a well known shop just for the sake of social status?why?'], columns=['do you find bargaining pleasing?'], aggfunc='count')
table
# Out:
# do you find bargaining pleasing?                    Maybe    No   Yes
# Do you think it is a good idea to go to a well ...
# I don't like it.                                      NaN   1.0   NaN
# I don't think it's a good idea                        NaN   NaN   1.0
# Maybe                                                 NaN   1.0   NaN
# NO,i don't think it is a good idea.                   NaN   NaN   1.0
# No                                                    2.0  14.0  11.0
# No . No need to waste money and valuable time         NaN   1.0   NaN
# No I dont need to                                     NaN   1.0   NaN
# No i dont think so.i think social status should...    NaN   1.0   NaN
# No, Its stupid                                        1.0   NaN   NaN
# No, absolutely the most ridiculous thing to do.       NaN   1.0   NaN
# No, i do shopping for myself                          NaN   NaN   1.0
# No,because managing economy and getting somethi...    NaN   1.0   NaN
# ...

# %%
df = df.dropna()

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('All_Data.csv')
table = pd.pivot_table(df, values='ID', index=['Gender','Do you think it is a good idea to go to a well known shop just for the sake of social status?why?'], columns=['do you find bargaining pleasing?'], aggfunc='count')
table
# Out:
# do you find bargaining pleasing?                           Maybe    No  Yes
# Gender Do you think it is a good idea to go to a well ...
# Female I don't think it's a good idea                        NaN   NaN  1.0
#        NO,i don't think it is a good idea.                   NaN   NaN  1.0
#        No                                                    1.0   2.0  4.0
#        No I dont need to                                     NaN   1.0  NaN
#        No, absolutely the most ridiculous thing to do.       NaN   1.0  NaN
#        No, i do shopping for myself                          NaN   NaN  1.0
#        No. I don't think so.                                 NaN   NaN  1.0
#        No. It is illogical.                                  NaN   1.0  NaN
#        No. It's totally childish                             1.0   NaN  NaN
#        No. Showing off is not the real happiness.            NaN   1.0  NaN
#        No. Sometimes well known shops charge more valu...    NaN   1.0  NaN
# ...

# %%
table.fillna(0)
# Out:
# do you find bargaining pleasing?                           Maybe    No  Yes
# Gender Do you think it is a good idea to go to a well ...
# Female I don't think it's a good idea                        0.0   0.0  1.0
#        NO,i don't think it is a good idea.                   0.0   0.0  1.0
#        No                                                    1.0   2.0  4.0
#        No I dont need to                                     0.0   1.0  0.0
#        No, absolutely the most ridiculous thing to do.       0.0   1.0  0.0
#        No, i do shopping for myself                          0.0   0.0  1.0
#        No. I don't think so.                                 0.0   0.0  1.0
#        No. It is illogical.                                  0.0   1.0  0.0
#        No. It's totally childish                             1.0   0.0  0.0
#        No. Showing off is not the real happiness.            0.0   1.0  0.0
#        No. Sometimes well known shops charge more valu...    0.0   1.0  0.0
# ...

# %%
table.unstack('Gender').plot(kind='bar')

# %%
table = pd.pivot_table(df, values='ID', index=['Gender','Would you still pursue your goal if the motive behind it is fulfilled in another way?'],  aggfunc='count')
table
# Out:
#                                                            ID
# Gender Would you still pursue your goal if the motive ...
# Female Maybe                                                3
#        No                                                   5
#        Probably                                             1
#        Yes                                                 22
# Male   Maybe                                               10
#        No                                                  15
#        Yes                                                 40

# %%
table.unstack('Gender').plot(kind='bar')
